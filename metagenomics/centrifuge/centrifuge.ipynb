# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import taxopy

# %%
df = pd.read_csv('data/centrifuge_report/report.N23.tsv', sep='\t')
df = df.sort_values(by="abundance", ascending=False)

# %%
total_abundance = df['abundance'].sum()
total_abundance
# Out:
# np.float64(1.0000005723974001)

# %%
df
# Out:
#                                name    taxID     taxRank  genomeSize  \
# 1168         Canis lupus familiaris     9615  subspecies  2482000080
# 1226     Bacteroides zoogleoformans    28119     species     3361794
# 14703         Prevotella sp. E15-22  2937774     species     3335334
# 5076    Porphyromonas crevioricanis   393921     species     2133352
# 1594    Porphyromonas cangingivalis    36874     species     2404857
# ...                             ...      ...         ...         ...
# 6022                Rhodothermaceae   563843      family           0
# 6023      Sphingomonas hankookensis   563996     species     3947172
# 6024                Spirosoma rigui   564064     species     5828404
# 6025   Ralstonia solanacearum MolK2   564065      strain     5586409
# 17808                Thalassobellus  3400333       genus           0
#
#        numReads  numUniqueReads  abundance
# 1168   18669448        17135144   0.623155
# 1226       3840            1112   0.093474
# ...

# %%
for row in range(len(df)):
    print(df.iloc[row][0])
    print(df.iloc[row][6])
# Out:
# /var/folders/ty/5bvjyd1n4dx2ymnhbn1s9579brngf7/T/ipykernel_3576/927671738.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df.iloc[row][0])
# /var/folders/ty/5bvjyd1n4dx2ymnhbn1s9579brngf7/T/ipykernel_3576/927671738.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df.iloc[row][6])
# Canis lupus familiaris
# 0.623155
# Bacteroides zoogleoformans
# 0.0934738
# Prevotella sp. E15-22
# 0.0534593
# Porphyromonas crevioricanis
# 0.0309493
# Porphyromonas cangingivalis
# 0.0184873
# Bacteroides heparinolyticus
# 0.0169303
# Porphyromonas endodontalis
# 0.0162625
# Frederiksenia canicola
# 0.0141722
# ...

# %%
taxdb = taxopy.TaxDb(nodes_dmp="../taxdb/nodes.dmp", names_dmp="../taxdb/names.dmp")
kingdoms = []
for row in range(len(df)):
    taxid = df.iloc[row]['taxID']
    key = "kingdom"
    dict = taxopy.Taxon(taxid, taxdb).rank_name_dictionary
    if key in dict:
        kingdoms.append(taxopy.Taxon(taxid, taxdb).rank_name_dictionary["kingdom"])
    else:
        kingdoms.append("NA")

df['kingdom'] = kingdoms

# %%
unique_superkingdoms = df['kingdom'].unique()
unique_superkingdoms
# Out:
# array(['Metazoa', 'Pseudomonadati', 'Fusobacteriati', 'Bacillati',
#        'Methanobacteriati', 'Thermotogati', 'NA', 'Thermoproteati',
#        'Nanobdellati', 'Promethearchaeati'], dtype=object)
